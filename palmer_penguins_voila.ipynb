# %% [markdown]
# Step-by-Step Guide for Creating and Deploying with Voilà and Binder
#
#     Set Up the Jupyter Notebook:
#         Start a new Jupyter notebook and install any necessary packages:

# %%
#best practice is to set up a virtual environment
#!pip install pandas seaborn matplotlib palmerpenguins voila
#!pip install palmerpenguins voila
#!pip install ipywidgets

# %% [markdown]
# Load the Palmer Penguins dataset:

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from palmerpenguins import load_penguins

# %%
# Load the dataset
penguins = load_penguins()

# %%
# Display dataset summary
print("Palmer Penguins Dataset Summary")
print(penguins.describe())

# %%
# Plotting - Bill Length vs. Bill Depth
plt.figure(figsize=(10, 6))
sns.scatterplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")
plt.title("Bill Length vs. Bill Depth by Penguin Species")
plt.xlabel("Bill Length (mm)")
plt.ylabel("Bill Depth (mm)")
plt.legend(title="Species")
plt.show()

# %%
# Histogram of Flipper Length
plt.figure(figsize=(10, 6))
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
plt.title("Flipper Length Distribution by Species")
plt.xlabel("Flipper Length (mm)")
plt.ylabel("Count")
plt.legend(title="Species")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Test Locally with Voilà:
#
#     Run
#     voila notebook_name.ipynb
#     in your terminal to preview the dashboard.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install pipreqs
#
# pipreqs ./ --force
#
# or use
#
# pip freeze > requirements.txt
#
#
# Prepare for Binder Deployment:
#
#     Push your notebook and a requirements.txt file to a GitHub repository:

# %% [markdown]
#     pandas
#     seaborn
#     matplotlib
#     palmerpenguins
#     voila

# %% [markdown]
# Generate the Binder link by visiting MyBinder.org, filling in the repo link, and specifying the path:
#
#         voila/render/your_notebook_name.ipynb
#         setting == URL

# %%
#!pip show palmerpenguins
